# %%
import numpy as np
import pyaudio
import wave
import matplotlib.pyplot as plt
import struct
from scipy.io import wavfile
import os
from sklearn.neural_network import MLPClassifier
import pandas as pd

# %%
samplerate, data = wavfile.read('./training/lid_off_full_run_1.wav')

#plt.plot(data)

data = data[60000:]

plt.plot(data)

print(data.size)
# Out:
# 420000

# %%
samplerate2, data2 = wavfile.read('./training/lid_off_full_run_2.wav')

#plt.plot(data)

data2 = data2[60000:]

plt.plot(data)
plt.plot(data2)

# %%
samplerate3, data3 = wavfile.read('./training/lid_off_full_run_3.wav')

data3 = data3[60000:]

plt.plot(data,  alpha=0.4)
plt.plot(data2, alpha=0.4)
plt.plot(data3, alpha=0.4)

# %%
for item in os.listdir("./training"):
    if item[0:7] == "lid_off":
        samplerate, data = wavfile.read(f'./training/{item}')
        data = data[60000:]
        print(max(data))
        plt.plot(data, alpha=0.3)
# Out:
# -14974976
# 65437696
# -10747904
# 78430208
# 69517312
# -15237120
# 14827520
# -23298048
# -4669440
# -10272768

# %%
samplerate, data = wavfile.read('./training/lid_off_full_run_1.wav')

#plt.plot(data)

data = data[60000:]

data = (data - data.mean()) / data.std()

data[data < 3] = 0



width = 1000
data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

first_peak = -1

for i in range(data.size):
    if( data[i] != 0 and first_peak == -1):
        first_peak = i
print(i)

plt.plot(data)
plt.axvline(x=first_peak, color="r")


data = data[first_peak:]
        
plt.plot(data)
# Out:
# 419

# %%
for item in os.listdir("./training"):
    if item[0:7] == "lid_off":
        samplerate, data = wavfile.read(f'./training/{item}')
        # trim first 60k samples (shortly after clap)
        data = data[60000:]
        # mean center and scale data
        data = (data - data.mean()) / data.std()
        # filter out all ambient noise (works for this application)
        data[data < 3] = 0
        
        # compresses data into bins to reduce dimentionality, works great after filter
        width = 100
        data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)
        
        # looks at the data for the first non-zero value (first peak in wave)
        first_peak = -1
        for i in range(data.size):
            if( data[i] != 0 and first_peak == -1):
                first_peak = i
        #trim from first peak onwards to end (sound runs long anways)
        data = data[first_peak:]
        
        # trims from end to have normalized size, scaled by width to accomidate different binning
        data = data[:int(3750_00/width)]
        plt.plot(data, alpha=0.3)
        #plt.axvline(x=first_peak, color="r")
plt.show()

# %%
for item in os.listdir("./training"):
    if item[0:7] == "lid_on_":
        samplerate, data = wavfile.read(f'./training/{item}')
        # trim first 60k samples (shortly after clap)
        data = data[60000:]
        # mean center and scale data
        data = (data - data.mean()) / data.std()
        # filter out all ambient noise (works for this application)
        data[data < 3] = 0
        
        # compresses data into bins to reduce dimentionality, works great after filter
        width = 100
        data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)
        
        # looks at the data for the first non-zero value (first peak in wave)
        first_peak = -1
        for i in range(data.size):
            if( data[i] != 0 and first_peak == -1):
                first_peak = i
        #trim from first peak onwards to end (sound runs long anways)
        data = data[first_peak:]
        
        # trims from end to have normalized size, scaled by width to accomidate different binning
        data = data[:int(3750_00/width)]
        plt.plot(data, alpha=0.3)
        #plt.axvline(x=first_peak, color="r")

plt.show()

# %%
def get_data(rel_dir):
    width = 1000
    trim_value = 3750_00
    x = []
    y = []
    
    for item in os.listdir(rel_dir):
        if item[0:7] == "lid_off" or item[0:15] == "testing_lid_off":
            y.append(0)
            samplerate, data = wavfile.read(f'{rel_dir}/{item}')
            # trim first 60k samples (shortly after clap)
            data = data[60000:]
            # mean center and scale data
            data = (data - data.mean()) / data.std()
            # filter out all ambient noise (works for this application)
            data[data < 3] = 0

            # compresses data into bins to reduce dimentionality, works great after filter
            data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

            # looks at the data for the first non-zero value (first peak in wave)
            first_peak = -1
            for i in range(data.size):
                if( data[i] != 0 and first_peak == -1):
                    first_peak = i
            #trim from first peak onwards to end (sound runs long anways)
            data = data[first_peak:]

            # trims from end to have normalized size, scaled by width to accomidate different binning
            data = data[:int(trim_value/width)]
            x.append(data)
            #plt.plot(data, alpha=0.3)
            #plt.axvline(x=first_peak, color="r")
        elif item[0:7] == "lid_on_" or item[0:15] == "testing_lid_on_":
            y.append(1)
            samplerate, data = wavfile.read(f'{rel_dir}/{item}')
            # trim first 60k samples (shortly after clap)
            data = data[60000:]
            # mean center and scale data
            data = (data - data.mean()) / data.std()
            # filter out all ambient noise (works for this application)
            data[data < 3] = 0

            # compresses data into bins to reduce dimentionality, works great after filter
            data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

            # looks at the data for the first non-zero value (first peak in wave)
            first_peak = -1
            for i in range(data.size):
                if( data[i] != 0 and first_peak == -1):
                    first_peak = i
            #trim from first peak onwards to end (sound runs long anways)
            data = data[first_peak:]

            # trims from end to have normalized size, scaled by width to accomidate different binning
            data = data[:int(trim_value/width)]
            x.append(data)
            #plt.plot(data, alpha=0.3)
            #plt.axvline(x=first_peak, color="r")
    plt.show()
    x = np.array(x)
    y = np.array(y)
    return x, y

# %%
x, y = get_data("./training")

nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(26,), random_state=1) #hidden_layer_sizes=(?,)
nn.fit(x,y);

xt, yt = get_data("./testing")


pred =  nn.predict(xt)

print(pd.crosstab(yt, pred))
# Out:
# col_0  0  1
# row_0
# 0      9  1
# 1      1  9

# %%
def get_data_by_state(lid_status, rel_dir): # lid_status = "lid_off" for off, or "lid_on_" for on data
    width = 1000
    trim_value = 3750_00
    x = []
    if lid_status == "lid_off":
        y = np.zeros(10)
    else:
        y = np.ones(10)
    
    for item in os.listdir(rel_dir):
        if item[0:7] == lid_status:
            samplerate, data = wavfile.read(f'{rel_dir}/{item}')
            # trim first 60k samples (shortly after clap)
            data = data[60000:]
            # mean center and scale data
            data = (data - data.mean()) / data.std()
            # filter out all ambient noise (works for this application)
            data[data < 3] = 0

            # compresses data into bins to reduce dimentionality, works great after filter
            data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

            # looks at the data for the first non-zero value (first peak in wave)
            first_peak = -1
            for i in range(data.size):
                if( data[i] != 0 and first_peak == -1):
                    first_peak = i
            #trim from first peak onwards to end (sound runs long anways)
            data = data[first_peak:]

            # trims from end to have normalized size, scaled by width to accomidate different binning
            data = data[:int(trim_value/width)]
            x.append(data)
            plt.plot(data, alpha=0.3)
            #plt.axvline(x=first_peak, color="r")
    plt.xlabel("Sample Number")
    plt.ylabel("Peak Magnitude")
    plt.title(f"{lid_status} Plot")
    plt.show()
    x = np.array(x)
    return x, y

# %%
x1, y1 = get_data_by_state("lid_off", "./training")
x2, y2 = get_data_by_state("lid_on_", "./training")

# %%
samplerate, data = wavfile.read('./training/lid_off_full_run_1.wav')

#plt.plot(data)

data = data[60000:]

data = (data - data.mean()) / data.std()

data = np.abs(data)
data[data < 3] = 0


width = 1000
data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

first_peak = -1

for i in range(data.size):
    if( data[i] != 0 and first_peak == -1):
        first_peak = i
print(i)

plt.plot(data)
plt.axvline(x=first_peak, color="r")


data = data[first_peak:]
        
plt.plot(data)
# Out:
# 419

# %%
samplerate, data = wavfile.read('./training/ambient_noise1.wav')

#plt.plot(data)

data = data[60000:]

data = (data - data.mean()) / data.std()

data = np.abs(data)
data[data < 3] = 0


width = 1000
data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

first_peak = -1

for i in range(data.size):
    if( data[i] != 0 and first_peak == -1):
        first_peak = i
print(i)

#plt.plot(data)
#plt.axvline(x=first_peak, color="r")


data = data[first_peak:]
        
plt.plot(data)
# Out:
# 419

# %%
samplerate, data = wavfile.read('./training/training_ambient_noise1.wav')

#plt.plot(data)

data = data[60000:]

data = (data - data.mean()) / data.std()

data = np.abs(data)
data[data < 3] = 0


width = 1000
data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

first_peak = -1

for i in range(data.size):
    if( data[i] != 0 and first_peak == -1):
        first_peak = i
print(i)

#plt.plot(data)
#plt.axvline(x=first_peak, color="r")


data = data[first_peak:]
        
plt.plot(data)
# Out:
# 419

# %%
samplerate, data = wavfile.read('./training/training_no_piece1.wav')

#plt.plot(data)

data = data[60000:]

data = (data - data.mean()) / data.std()

data = np.abs(data)
data[data < 3] = 0


width = 1000
data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

first_peak = -1

for i in range(data.size):
    if( data[i] != 0 and first_peak == -1):
        first_peak = i
print(i)

#plt.plot(data)
#plt.axvline(x=first_peak, color="r")


data = data[first_peak:]
        
plt.plot(data)
# Out:
# 419

# %%
for item in os.listdir('./training'):
    if item[0:16] == "training_no_piec":
        if(item[-5] != '3'):
            samplerate, data = wavfile.read(f'./training/{item}')
            data = data[60000:]
            data = (data - data.mean()) / data.std()
            data = np.abs(data)
            data = data **2
            plt.plot(data, alpha = 0.6)

# %%
for item in os.listdir('./training'):
    if item[0:16] == "training_ambient":
        samplerate, data = wavfile.read(f'./training/{item}')
        data = data[60000:]
        data = (data - data.mean()) / data.std()
        data = np.abs(data)
        data = data **2
        plt.plot(data, alpha = 0.6)

# %%
samplerate, data = wavfile.read(f'./training/training_no_piece3.wav')
data = data[60000:]
data = (data - data.mean())
data = np.abs(data)
data = data **2
plt.plot(data, alpha = 0.6)

# %%
def get_data_all_classes(rel_dir):
    width = 1000
    trim_value = 3700_00
    x = []
    y = []
    
    for item in os.listdir(rel_dir):
        if item[0:7] == "lid_off" or item[0:15] == "testing_lid_off":
            y.append(0)
            samplerate, data = wavfile.read(f'{rel_dir}/{item}')
            # trim first 60k samples (shortly after clap)
            data = data[60000:]
            # mean center and scale data
            data = (data - data.mean()) / data.std()
            # filter out all ambient noise (works for this application)
            data[data < 3] = 0

            # compresses data into bins to reduce dimentionality, works great after filter
            data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

            # looks at the data for the first non-zero value (first peak in wave)
            first_peak = -1
            for i in range(data.size):
                if( data[i] != 0 and first_peak == -1):
                    first_peak = i
            #trim from first peak onwards to end (sound runs long anways)
            data = data[first_peak:]

            # trims from end to have normalized size, scaled by width to accomidate different binning
            data = data[:int(trim_value/width)]
            x.append(data)
            #plt.plot(data, alpha=0.3)
            #plt.axvline(x=first_peak, color="r")
        elif item[0:7] == "lid_on_" or item[0:15] == "testing_lid_on_":
            y.append(1)
            samplerate, data = wavfile.read(f'{rel_dir}/{item}')
            # trim first 60k samples (shortly after clap)
            data = data[60000:]
            # mean center and scale data
            data = (data - data.mean()) / data.std()
            # filter out all ambient noise (works for this application)
            data[data < 3] = 0

            # compresses data into bins to reduce dimentionality, works great after filter
            data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

            # looks at the data for the first non-zero value (first peak in wave)
            first_peak = -1
            for i in range(data.size):
                if( data[i] != 0 and first_peak == -1):
                    first_peak = i
            #trim from first peak onwards to end (sound runs long anways)
            data = data[first_peak:]

            # trims from end to have normalized size, scaled by width to accomidate different binning
            data = data[:int(trim_value/width)]
            x.append(data)
            #plt.plot(data, alpha=0.3)
            #plt.axvline(x=first_peak, color="r")
        elif item[0:15] == "testing_no_piec" or item[0:15] == "training_no_pie":
            y.append(2)
            samplerate, data = wavfile.read(f'{rel_dir}/{item}')
            # trim first 60k samples (shortly after clap)
            data = data[60000:]
            # mean center and scale data
            data = (data - data.mean()) / data.std()
            # filter out all ambient noise (works for this application)
            data[data < 3] = 0

            # compresses data into bins to reduce dimentionality, works great after filter
            data = data[:(data.size // width) * width].reshape(-1, width).mean(axis=1)

            # looks at the data for the first non-zero value (first peak in wave)
            first_peak = -1
            for i in range(data.size):
                if( data[i] != 0 and first_peak == -1):
                    first_peak = i
            #trim from first peak onwards to end (sound runs long anways)
            data = data[first_peak:]

            # trims from end to have normalized size, scaled by width to accomidate different binning
            data = data[:int(trim_value/width)]
            x.append(data)
            #plt.plot(data, alpha=0.3)
            #plt.axvline(x=first_peak, color="r")
    plt.show()
    x = np.array(x)
    y = np.array(y)
    return x, y

# %%
x, y = get_data_all_classes("./training")

    
nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(26,), random_state=1) #hidden_layer_sizes=(?,)
nn.fit(x,y);

xt, yt = get_data_all_classes("./testing")


pred =  nn.predict(xt)

print(pd.crosstab(yt, pred))
# Out:
# C:\Users\jared\AppData\Local\Temp/ipykernel_3520/701104818.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.array(x)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3520/3295884300.py in <module>
#       3
#       4 nn = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(26,), random_state=1) #hidden_layer_sizes=(?,)
# ----> 5 nn.fit(x,y);
#       6
#       7 xt, yt = get_data_all_classes("./testing")
#
# ~\miniconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#     671         self : returns a trained MLP model.
#     672         """
# --> 673         return self._fit(X, y, incremental=False)
#     674
#     675     @property
#
# ~\miniconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     362                       (not self.warm_start and not incremental))
#     363
# --> 364         X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     365
#     366         n_samples, n_features = X.shape
#
# ~\miniconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _validate_input(self, X, y, incremental, reset)
#     969
#     970     def _validate_input(self, X, y, incremental, reset):
# --> 971         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
#     972                                    multi_output=True,
#     973                                    dtype=(np.float64, np.float32),
#
# ~\miniconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\miniconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# ~\miniconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\miniconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# ValueError: setting an array element with a sequence.

# %%
for item in os.listdir("./testing/"):
    print(item[0:15])
# Out:
# testing_ambient
# testing_ambient
# testing_ambient
# testing_ambient
# testing_ambient
# testing_consecu
# testing_consecu
# testing_consecu
# testing_consecu
# testing_consecu
# testing_consecu
# testing_consecu
# testing_consecu
# testing_consecu
# testing_consecu
# testing_full1.w
# testing_full10.
# testing_full2.w
# testing_full3.w
# testing_full4.w
# testing_full5.w
# testing_full6.w
# testing_full7.w
# testing_full8.w
# testing_full9.w
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_off
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_lid_on_
# testing_no_piec
# testing_no_piec
# testing_no_piec
# testing_no_piec
# testing_no_piec
